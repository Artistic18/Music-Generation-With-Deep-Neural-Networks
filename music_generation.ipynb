# %% [markdown]
# <a href="https://colab.research.google.com/github/Artistic18/Music-Generation-With-Deep-Neural-Networks/blob/master/music_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import glob
import pickle
import numpy
from music21 import converter, instrument, note, chord
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import Activation
from keras.layers import BatchNormalization as BatchNorm
from keras.utils  import np_utils
from keras.callbacks import ModelCheckpoint

# %%
def train_network():
    notes = get_data()
    n_vocab = len(set(notes))
    network_ip, network_op = input_sequence(notes, n_vocab)
    model = create_network(network_ip, n_vocab)
    train(model, network_ip, network_op)
    
def get_data():
    notes = []
    for song in glob.glob("drive/My Drive/music generation with tensorflow/midi_songs/*.mid"):
        midi = converter.parse(song)
        print("Parsing %s" % song)
        notes_to_parse = None
        
        try: 
            s2 = instrument.partitionByInstrument(midi)
            notes_to_parse = s2.parts[0].recurse() 
        except: 
            notes_to_parse = midi.flat.notes
        
        for element in notes_to_parse:
            if isinstance(element, note.Note):
                notes.append(str(element.pitch))
            elif isinstance(element, chord.Chord):
                notes.append('.'.join(str(n) for n in element.normalOrder))

        
      
    return notes

def input_sequence(notes,n_vocab):
    sequence_length = 100
    pitchnames = sorted(set(i for i in notes))
    
    note_to_int = dict((note, number) for number, note in enumerate(pitchnames))
    network_ip = []
    network_op = []
    
    for i in range(0, len(notes) - sequence_length, 1):
        sequence_in = notes[i:i + sequence_length]
        sequence_out = notes[i + sequence_length]
        network_ip.append([note_to_int[char] for char in sequence_in])
        network_op.append(note_to_int[sequence_out])
    n_patterns = len(network_ip)
        
    network_ip = numpy.reshape(network_ip, (n_patterns,sequence_length,1))
    network_ip = network_ip / float(n_vocab)
    network_op = np_utils.to_categorical(network_op)
    
    return (network_ip,network_op)

def create_network(network_ip, n_vocab):
    model = Sequential()
    model.add(LSTM(
        512,
        input_shape=(network_ip.shape[1], network_ip.shape[2]),
        recurrent_dropout = 0.3,
        return_sequences = True
    ))
    model.add(LSTM(512, return_sequences=True, recurrent_dropout=0.3))
    model.add(LSTM(512))
    model.add(BatchNorm())
    model.add(Dropout(0.3))
    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(Dropout(0.3))
    model.add(Dense(n_vocab))
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='rmsprop')
    
    return model

def train(model, network_ip, network_op):
    filepath = "weights-improvement-{epoch:02d}-{loss:.4f}-bigger.hdf5"
    checkpoint = ModelCheckpoint(
            filepath,
            monitor='loss',
            verbose=True,
            save_best_only=True,
            mode='min'
            )
    callbacks_list = [checkpoint]
    model.fit(network_ip, network_op, epochs=200, batch_size=128, callbacks=callbacks_list)

# %%
if __name__ == '__main__':
    train_network()
# Out:
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/electric_de_chocobo.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/ViviinAlexandria.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Rydia_pc.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/ff4_piano_collections-main_theme.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/FF4.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/thenightmarebegins.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/sera_.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/ff7-mainmidi.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/ff4-airship.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/goldsaucer.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/bcm.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/ff8-lfp.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/balamb.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Fyw_piano.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/thoughts.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/costadsol.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Ff7-Cinco.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Finalfantasy6fanfarecomplete.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/FFIX_Piano.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/FF8_Shuffle_or_boogie_pc.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/ff11_awakening_piano.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/tpirtsd-piano.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/gerudo.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/redwings.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/ff4-town.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/BlueStone_LastDungeon.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/ff4-fight1.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Gold_Silver_Rival_Battle.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/OTD5YA.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/waltz_de_choco.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/z_aeristhemepiano.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/JENOVA.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Still_Alive-1.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Final_Fantasy_7_-_Judgement_Day_Piano.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/DOS.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Ff7-One_Winged.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Final_Fantasy_Matouyas_Cave_Piano.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/lurk_in_dark.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/figaro.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Ff7-Jenova_Absolute.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/ff6shap.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/fortresscondor.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/FF3_Battle_(Piano).mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/FFIII_Edgar_And_Sabin_Piano.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Cids.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/8.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/caitsith.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Zelda_Overworld.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/AT.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/pkelite4.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Kingdom_Hearts_Traverse_Town.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/tifap.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/cosmo.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/FFVII_BATTLE.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/FFX_-_Ending_Theme_(Piano_Version)_-_by_Angel_FF.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/dontbeafraid.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/great_war.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/sandy.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/ff1battp.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Rachel_Piano_tempofix.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/ultros.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Life_Stream.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Kingdom_Hearts_Dearly_Beloved.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Fierce_Battle_(Piano).mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/EyesOnMePiano.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/path_of_repentance.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/0fithos.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/FF6epitaph_piano.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/mining.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/FFIXQuMarshP.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Eternal_Harvest.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Suteki_Da_Ne_(Piano_Version).mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Ff4-BattleLust.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Fiend_Battle_(Piano).mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/relmstheme-piano.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/decisive.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/ahead_on_our_way_piano.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Oppressed.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/roseofmay-piano.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/ff7themep.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/braska.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/HighwindTakestotheSkies.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/sobf.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/In_Zanarkand.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/VincentPiano.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/traitor.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/dayafter.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/ff4pclov.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/rufus.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/Finalfantasy5gilgameshp.mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/FF3_Third_Phase_Final_(Piano).mid
# Parsing drive/My Drive/music generation with tensorflow/midi_songs/ultimafro.mid
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch 1/200
# 446/446 [==============================] - ETA: 0s - loss: 4.6695
# Epoch 00001: loss improved from inf to 4.66954, saving model to weights-improvement-01-4.6695-bigger.hdf5
# 446/446 [==============================] - 240s 539ms/step - loss: 4.6695
# Epoch 2/200
# 446/446 [==============================] - ETA: 0s - loss: 4.5570
# Epoch 00002: loss improved from 4.66954 to 4.55695, saving model to weights-improvement-02-4.5570-bigger.hdf5
# 446/446 [==============================] - 242s 542ms/step - loss: 4.5570
# Epoch 3/200
# 104/446 [=====>........................] - ETA: 3:04 - loss: 4.5538
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-10c064a65f30> in <module>()
#       1 if __name__ == '__main__':
# ----> 2     train_network()
#
# <ipython-input-9-9445878c6f3c> in train_network()
#       4     network_ip, network_op = input_sequence(notes, n_vocab)
#       5     model = create_network(network_ip, n_vocab)
# ----> 6     train(model, network_ip, network_op)
#       7
#       8 def get_data():
#
# <ipython-input-9-9445878c6f3c> in train(model, network_ip, network_op)
#      81             )
#      82     callbacks_list = [checkpoint]
# ---> 83     model.fit(network_ip, network_op, epochs=200, batch_size=128, callbacks=callbacks_list)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
